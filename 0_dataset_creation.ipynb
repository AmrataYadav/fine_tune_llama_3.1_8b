# %% [markdown]
# #0. Installations

# %%
# !pip install -q datasets
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 5.6 MB/s eta 0:00:00

# %%
# !pip install -q huggingface_hub

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: write).
# The token `Amrata Yadav` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# ...

# %% [markdown]
# # 1. Data

# %%
data = [
  {
    "question": "How does monetary policy influence inflation rates?",
    "retrieved_chunks": [
      "Central banks implement monetary policy through instruments such as interest rate adjustments, open market operations, and reserve requirements. By lowering interest rates, banks aim to stimulate borrowing and investment, while raising rates is used to cool down an overheating economy and mitigate inflationary pressures.",
      "Inflation is affected by the quantity of money in circulation relative to goods and services available in the economy. When central banks increase the money supply without a corresponding increase in production, the value of money can decrease, leading to higher prices for consumers.",
      "In addition to economic factors, central banks sometimes take into account political stability and international market trends when deciding on policy changes. However, these considerations are more peripheral and do not directly explain the mechanism through which monetary policy impacts inflation."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Central banks implement monetary policy through instruments such as interest rate adjustments, open market operations, and reserve requirements. By lowering interest rates, banks aim to stimulate borrowing and investment, while raising rates is used to cool down an overheating economy and mitigate inflationary pressures.",
        "Inflation is affected by the quantity of money in circulation relative to goods and services available in the economy. When central banks increase the money supply without a corresponding increase in production, the value of money can decrease, leading to higher prices for consumers."
      ]
    }
  },
  {
    "question": "What factors contribute to stock market volatility?",
    "retrieved_chunks": [
      "Stock market volatility is often driven by investor sentiment, which can be influenced by a variety of factors including economic indicators, corporate earnings reports, and geopolitical events. Market psychology plays a crucial role, as rapid changes in sentiment can lead to sharp market movements even in the absence of significant economic news.",
      "Other factors contributing to volatility include liquidity levels and trading volumes. In markets with low liquidity, even modest trades can result in large price swings, thereby exacerbating volatility. Additionally, algorithmic trading and high-frequency trading have introduced new dimensions of risk that can trigger rapid fluctuations.",
      "Macroeconomic policies such as fiscal stimulus and monetary easing can indirectly influence stock market trends by affecting overall economic growth and investor confidence. However, these policies tend to have a gradual effect and are less likely to cause sudden market swings compared to factors like market sentiment and liquidity."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Stock market volatility is often driven by investor sentiment, which can be influenced by a variety of factors including economic indicators, corporate earnings reports, and geopolitical events. Market psychology plays a crucial role, as rapid changes in sentiment can lead to sharp market movements even in the absence of significant economic news.",
        "Other factors contributing to volatility include liquidity levels and trading volumes. In markets with low liquidity, even modest trades can result in large price swings, thereby exacerbating volatility. Additionally, algorithmic trading and high-frequency trading have introduced new dimensions of risk that can trigger rapid fluctuations."
      ]
    }
  },
  {
    "question": "How does diversification reduce investment risk?",
    "retrieved_chunks": [
      "Diversification involves spreading investments across various asset classes, industries, and geographies to minimize exposure to any single risk. By not concentrating all capital in one type of asset, investors can reduce the volatility of their portfolio and mitigate potential losses from any one underperforming segment.",
      "The concept of diversification is rooted in modern portfolio theory, which emphasizes that a well-balanced portfolio can achieve higher risk-adjusted returns. Diversification works by offsetting losses in one investment with gains in another, particularly when the assets are not perfectly correlated.",
      "Market timing and active trading strategies, while sometimes effective, are generally considered more speculative and do not provide the same risk mitigation benefits as diversification. Investors who focus on market timing often expose themselves to additional risks, as predicting short-term market movements is highly uncertain."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Diversification involves spreading investments across various asset classes, industries, and geographies to minimize exposure to any single risk. By not concentrating all capital in one type of asset, investors can reduce the volatility of their portfolio and mitigate potential losses from any one underperforming segment.",
        "The concept of diversification is rooted in modern portfolio theory, which emphasizes that a well-balanced portfolio can achieve higher risk-adjusted returns. Diversification works by offsetting losses in one investment with gains in another, particularly when the assets are not perfectly correlated."
      ]
    }
  },
  {
    "question": "What role does fiscal policy play in economic growth?",
    "retrieved_chunks": [
      "Fiscal policy, which involves government spending and taxation decisions, plays a significant role in stimulating economic growth during periods of recession. Increased government spending can boost demand, while tax cuts can increase disposable income for consumers, both of which can contribute to a higher rate of economic activity.",
      "Economic growth is influenced by a myriad of factors, including technological innovation, consumer confidence, and global trade dynamics. While fiscal policy is a critical tool, its effectiveness can be moderated by other external factors that impact the overall business environment.",
      "The impact of fiscal policy is also subject to political considerations, where budget constraints and public debt levels can limit the scope of spending initiatives. Moreover, the multiplier effect of fiscal spending may vary depending on the state of the economy and the efficiency of government programs."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Fiscal policy, which involves government spending and taxation decisions, plays a significant role in stimulating economic growth during periods of recession. Increased government spending can boost demand, while tax cuts can increase disposable income for consumers, both of which can contribute to a higher rate of economic activity.",
        "The impact of fiscal policy is also subject to political considerations, where budget constraints and public debt levels can limit the scope of spending initiatives. Moreover, the multiplier effect of fiscal spending may vary depending on the state of the economy and the efficiency of government programs."
      ]
    }
  },
  {
    "question": "How do currency exchange rates affect international trade?",
    "retrieved_chunks": [
      "Currency exchange rates determine the relative value of different currencies, which in turn affects the price competitiveness of exports and imports. A depreciation of a country's currency can make its exports cheaper and more attractive to foreign buyers, while making imports more expensive, thereby affecting the trade balance.",
      "International trade is influenced by various factors including trade agreements, tariffs, and global supply chains. While currency exchange rates play a role, they are only one component of the complex interplay of factors that determine trade flows between nations.",
      "Fluctuations in exchange rates can lead to significant uncertainties for businesses engaged in international trade. Companies may hedge against these risks using financial instruments such as futures, options, and swaps, which help stabilize profits despite volatile currency movements."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Currency exchange rates determine the relative value of different currencies, which in turn affects the price competitiveness of exports and imports. A depreciation of a country's currency can make its exports cheaper and more attractive to foreign buyers, while making imports more expensive, thereby affecting the trade balance.",
        "Fluctuations in exchange rates can lead to significant uncertainties for businesses engaged in international trade. Companies may hedge against these risks using financial instruments such as futures, options, and swaps, which help stabilize profits despite volatile currency movements."
      ]
    }
  },
  {
    "question": "What is the impact of quantitative easing on financial markets?",
    "retrieved_chunks": [
      "Quantitative easing (QE) involves large-scale asset purchases by central banks to inject liquidity into the financial system. This policy aims to lower long-term interest rates and encourage increased lending and investment.",
      "The increase in money supply through QE can lead to higher asset prices, as investors search for yield in a low-interest-rate environment, potentially inflating stock and bond markets.",
      "While QE is designed to stimulate economic growth, it can also result in unintended consequences such as asset bubbles or long-term inflation if the increased liquidity is not managed properly."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Quantitative easing (QE) involves large-scale asset purchases by central banks to inject liquidity into the financial system. This policy aims to lower long-term interest rates and encourage increased lending and investment.",
        "The increase in money supply through QE can lead to higher asset prices, as investors search for yield in a low-interest-rate environment, potentially inflating stock and bond markets."
      ]
    }
  },
  {
    "question": "How does leverage affect a company's financial performance?",
    "retrieved_chunks": [
      "Leverage, which involves the use of debt to finance operations, can amplify a company's returns on equity when business conditions are favorable. However, excessive leverage increases the risk of financial distress during economic downturns.",
      "Companies with high levels of leverage may face higher interest expenses, which can reduce net income and ultimately impact profitability. The balance between debt and equity is crucial for maintaining financial stability.",
      "While leverage can provide growth opportunities by funding expansion, it also exposes companies to volatile market conditions and can lead to significant losses if revenue streams are disrupted."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Leverage, which involves the use of debt to finance operations, can amplify a company's returns on equity when business conditions are favorable. However, excessive leverage increases the risk of financial distress during economic downturns.",
        "Companies with high levels of leverage may face higher interest expenses, which can reduce net income and ultimately impact profitability. The balance between debt and equity is crucial for maintaining financial stability."
      ]
    }
  },
  {
    "question": "What are the risks associated with high-frequency trading?",
    "retrieved_chunks": [
      "High-frequency trading (HFT) leverages sophisticated algorithms and high-speed data networks to execute trades in fractions of a second, which can contribute to market liquidity under normal conditions.",
      "However, the speed and volume of HFT can also exacerbate market volatility, leading to flash crashes and sudden liquidity shortages as automated systems react to market events in real-time.",
      "Additionally, the complexity of HFT strategies raises concerns about market fairness and regulatory oversight, as it may disadvantage traditional investors who do not have access to similar technology."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "High-frequency trading (HFT) leverages sophisticated algorithms and high-speed data networks to execute trades in fractions of a second, which can contribute to market liquidity under normal conditions.",
        "However, the speed and volume of HFT can also exacerbate market volatility, leading to flash crashes and sudden liquidity shortages as automated systems react to market events in real-time."
      ]
    }
  },
  {
    "question": "How do interest rate changes impact bond prices?",
    "retrieved_chunks": [
      "Bond prices and interest rates have an inverse relationship; when interest rates rise, existing bond prices typically fall as new bonds are issued at higher yields.",
      "This inverse relationship is driven by the fact that the fixed interest payments of existing bonds become less attractive compared to the new bonds offering higher returns, leading to a discount on the older bonds.",
      "Market expectations about future interest rate movements can further influence bond prices, as investors adjust their portfolios in anticipation of changes in monetary policy and economic conditions."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Bond prices and interest rates have an inverse relationship; when interest rates rise, existing bond prices typically fall as new bonds are issued at higher yields.",
        "This inverse relationship is driven by the fact that the fixed interest payments of existing bonds become less attractive compared to the new bonds offering higher returns, leading to a discount on the older bonds.",
        "Market expectations about future interest rate movements can further influence bond prices, as investors adjust their portfolios in anticipation of changes in monetary policy and economic conditions."
      ]
    }
  },
  {
    "question": "What is the significance of credit ratings in the financial markets?",
    "retrieved_chunks": [
      "Credit ratings, provided by agencies such as Moody's and Standard & Poor's, assess the creditworthiness of borrowers and help investors gauge the risk associated with debt instruments.",
      "These ratings influence the interest rates that borrowers must pay, as lower-rated entities typically face higher borrowing costs to compensate for perceived risk.",
      "In addition to guiding investor decisions, credit ratings can impact regulatory requirements for financial institutions, thereby affecting market liquidity and capital allocation."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Credit ratings, provided by agencies such as Moody's and Standard & Poor's, assess the creditworthiness of borrowers and help investors gauge the risk associated with debt instruments.",
        "These ratings influence the interest rates that borrowers must pay, as lower-rated entities typically face higher borrowing costs to compensate for perceived risk.",
        "In addition to guiding investor decisions, credit ratings can impact regulatory requirements for financial institutions, thereby affecting market liquidity and capital allocation."
      ]
    }
  },
  {
    "question": "How does a company's dividend policy influence its stock price?",
    "retrieved_chunks": [
      "Dividend policy can signal a company's financial health and future prospects; steady or increasing dividends often attract income-focused investors, potentially boosting the stock price.",
      "The sustainability of dividends is closely monitored, and unexpected changes in dividend payments can lead to market re-evaluations of the company's valuation.",
      "However, some companies may choose to reinvest earnings for growth rather than distribute dividends, which can also be interpreted as a positive signal for long-term investors."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Dividend policy can signal a company's financial health and future prospects; steady or increasing dividends often attract income-focused investors, potentially boosting the stock price.",
        "The sustainability of dividends is closely monitored, and unexpected changes in dividend payments can lead to market re-evaluations of the company's valuation."
      ]
    }
  },
  {
    "question": "What are the key differences between growth and value investing?",
    "retrieved_chunks": [
      "Growth investing focuses on companies expected to grow at an above-average rate, often reinvesting earnings to fuel expansion, while value investing targets companies that appear undervalued relative to their fundamentals.",
      "Investors in growth stocks typically accept higher valuations based on future earnings potential, whereas value investors look for stocks that trade at a discount to their intrinsic value.",
      "The two strategies differ in risk profiles as well; growth stocks may offer higher returns but come with increased volatility, while value stocks tend to be more stable but may have slower appreciation."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Growth investing focuses on companies expected to grow at an above-average rate, often reinvesting earnings to fuel expansion, while value investing targets companies that appear undervalued relative to their fundamentals.",
        "Investors in growth stocks typically accept higher valuations based on future earnings potential, whereas value investors look for stocks that trade at a discount to their intrinsic value.",
        "The two strategies differ in risk profiles as well; growth stocks may offer higher returns but come with increased volatility, while value stocks tend to be more stable but may have slower appreciation."
      ]
    }
  },
  {
    "question": "How does inflation affect fixed income investments?",
    "retrieved_chunks": [
      "Inflation erodes the purchasing power of the fixed returns provided by bonds and other fixed income instruments, making them less attractive during periods of high inflation.",
      "Investors often demand higher yields on fixed income securities during inflationary periods to compensate for the loss in real value of their returns.",
      "Inflation-indexed bonds, such as Treasury Inflation-Protected Securities (TIPS), are designed to mitigate this risk by adjusting the principal value with inflation rates, though they typically offer lower base yields."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Inflation erodes the purchasing power of the fixed returns provided by bonds and other fixed income instruments, making them less attractive during periods of high inflation.",
        "Investors often demand higher yields on fixed income securities during inflationary periods to compensate for the loss in real value of their returns.",
        "Inflation-indexed bonds, such as Treasury Inflation-Protected Securities (TIPS), are designed to mitigate this risk by adjusting the principal value with inflation rates, though they typically offer lower base yields."
      ]
    }
  },
  {
    "question": "What is the role of regulatory bodies in maintaining market stability?",
    "retrieved_chunks": [
      "Regulatory bodies, such as the Securities and Exchange Commission (SEC) and the Financial Conduct Authority (FCA), establish and enforce rules to ensure transparency and fairness in financial markets.",
      "These organizations monitor trading activities, implement measures to prevent market manipulation, and work to protect investors from fraudulent practices.",
      "While regulators play a critical role in maintaining stability, overly stringent regulations can sometimes hinder market innovation and liquidity, creating a delicate balance between oversight and freedom."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Regulatory bodies, such as the Securities and Exchange Commission (SEC) and the Financial Conduct Authority (FCA), establish and enforce rules to ensure transparency and fairness in financial markets.",
        "These organizations monitor trading activities, implement measures to prevent market manipulation, and work to protect investors from fraudulent practices.",
        "While regulators play a critical role in maintaining stability, overly stringent regulations can sometimes hinder market innovation and liquidity, creating a delicate balance between oversight and freedom."
      ]
    }
  },
  {
    "question": "How do mergers and acquisitions affect shareholder value?",
    "retrieved_chunks": [
      "Mergers and acquisitions (M&A) can create synergies by combining resources and reducing costs, potentially leading to enhanced shareholder value through improved profitability.",
      "However, M&A activities also carry risks, such as integration challenges, cultural clashes, and the possibility of overpaying for acquisitions, which can negatively impact stock prices.",
      "The market reaction to M&A announcements often reflects investor sentiment and expectations about the future performance of the combined entity, with favorable deals generally boosting share prices."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Mergers and acquisitions (M&A) can create synergies by combining resources and reducing costs, potentially leading to enhanced shareholder value through improved profitability.",
        "However, M&A activities also carry risks, such as integration challenges, cultural clashes, and the possibility of overpaying for acquisitions, which can negatively impact stock prices.",
        "The market reaction to M&A announcements often reflects investor sentiment and expectations about the future performance of the combined entity, with favorable deals generally boosting share prices."
      ]
    }
  },
  {
    "question": "What are the benefits and drawbacks of algorithmic trading?",
    "retrieved_chunks": [
      "Algorithmic trading utilizes computer algorithms to execute trades at high speed and efficiency, often reducing transaction costs and improving market liquidity.",
      "The precision and speed of algorithmic trading can capture fleeting market opportunities, but it may also contribute to market instability and amplify volatility during periods of rapid price movements.",
      "Critics argue that the reliance on automated systems can lead to unforeseen errors and flash crashes, while proponents highlight its role in streamlining trading operations and increasing market efficiency."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Algorithmic trading utilizes computer algorithms to execute trades at high speed and efficiency, often reducing transaction costs and improving market liquidity.",
        "The precision and speed of algorithmic trading can capture fleeting market opportunities, but it may also contribute to market instability and amplify volatility during periods of rapid price movements.",
        "Critics argue that the reliance on automated systems can lead to unforeseen errors and flash crashes, while proponents highlight its role in streamlining trading operations and increasing market efficiency."
      ]
    }
  },
  {
    "question": "How does a leveraged buyout (LBO) work?",
    "retrieved_chunks": [
      "A leveraged buyout (LBO) involves acquiring a company primarily through borrowed funds, with the target's assets often serving as collateral for the debt.",
      "The strategy relies on the expectation that the acquired company will generate sufficient cash flow to service the debt, leading to potential high returns if the acquisition is successful.",
      "While LBOs can provide opportunities for significant financial gains, they also increase the risk profile of the acquisition, as high levels of debt can lead to financial distress if cash flows underperform."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "A leveraged buyout (LBO) involves acquiring a company primarily through borrowed funds, with the target's assets often serving as collateral for the debt.",
        "The strategy relies on the expectation that the acquired company will generate sufficient cash flow to service the debt, leading to potential high returns if the acquisition is successful.",
        "While LBOs can provide opportunities for significant financial gains, they also increase the risk profile of the acquisition, as high levels of debt can lead to financial distress if cash flows underperform."
      ]
    }
  },
  {
    "question": "What impact do geopolitical events have on commodity prices?",
    "retrieved_chunks": [
      "Geopolitical events, such as conflicts or trade embargoes, can disrupt supply chains and reduce the availability of key commodities, thereby driving up prices.",
      "The uncertainty surrounding political instability often leads investors to hedge by investing in commodities, which can further drive up prices during periods of turmoil.",
      "Conversely, positive geopolitical developments or diplomatic resolutions may restore supply and reduce investor panic, leading to a stabilization or even decline in commodity prices."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Geopolitical events, such as conflicts or trade embargoes, can disrupt supply chains and reduce the availability of key commodities, thereby driving up prices.",
        "The uncertainty surrounding political instability often leads investors to hedge by investing in commodities, which can further drive up prices during periods of turmoil.",
        "Conversely, positive geopolitical developments or diplomatic resolutions may restore supply and reduce investor panic, leading to a stabilization or even decline in commodity prices."
      ]
    }
  },
  {
    "question": "How do tax policies influence corporate investment decisions?",
    "retrieved_chunks": [
      "Tax incentives, such as credits and deductions, can encourage companies to invest in capital projects and research and development by lowering the effective cost of these expenditures.",
      "Changes in corporate tax rates can have a significant impact on after-tax profits, influencing decisions on whether to expand operations, invest in new technology, or pursue mergers and acquisitions.",
      "While favorable tax policies can stimulate investment, uncertainty in tax regulations may cause companies to delay or modify their investment plans, impacting overall economic growth."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Tax incentives, such as credits and deductions, can encourage companies to invest in capital projects and research and development by lowering the effective cost of these expenditures.",
        "Changes in corporate tax rates can have a significant impact on after-tax profits, influencing decisions on whether to expand operations, invest in new technology, or pursue mergers and acquisitions.",
        "While favorable tax policies can stimulate investment, uncertainty in tax regulations may cause companies to delay or modify their investment plans, impacting overall economic growth."
      ]
    }
  },
  {
    "question": "What are the advantages of investing in emerging markets?",
    "retrieved_chunks": [
      "Investing in emerging markets can offer higher growth potential compared to developed economies, driven by factors such as rapid industrialization, favorable demographics, and increasing consumer demand.",
      "Emerging markets often provide diversification benefits, as their economic cycles may differ from those of established markets, reducing overall portfolio risk.",
      "However, investments in these markets come with higher risks, including political instability, currency volatility, and less mature regulatory frameworks."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Investing in emerging markets can offer higher growth potential compared to developed economies, driven by factors such as rapid industrialization, favorable demographics, and increasing consumer demand.",
        "Emerging markets often provide diversification benefits, as their economic cycles may differ from those of established markets, reducing overall portfolio risk.",
        "However, investments in these markets come with higher risks, including political instability, currency volatility, and less mature regulatory frameworks."
      ]
    }
  },
  {
    "question": "How does market liquidity affect trading strategies?",
    "retrieved_chunks": [
      "Market liquidity refers to the ease with which assets can be bought or sold without causing significant price movements. High liquidity enables traders to enter and exit positions quickly.",
      "In illiquid markets, even small trades can lead to large price fluctuations, making it challenging for traders to execute their strategies effectively.",
      "Trading strategies often incorporate liquidity measures to manage risk, with high-frequency traders and institutional investors particularly focused on liquidity to optimize trade execution."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Market liquidity refers to the ease with which assets can be bought or sold without causing significant price movements. High liquidity enables traders to enter and exit positions quickly.",
        "In illiquid markets, even small trades can lead to large price fluctuations, making it challenging for traders to execute their strategies effectively.",
        "Trading strategies often incorporate liquidity measures to manage risk, with high-frequency traders and institutional investors particularly focused on liquidity to optimize trade execution."
      ]
    }
  },
  {
    "question": "What factors contribute to the pricing of derivatives?",
    "retrieved_chunks": [
      "The pricing of derivatives, such as options and futures, is influenced by factors including the underlying asset's price, volatility, time to expiration, and prevailing interest rates.",
      "Mathematical models like the Black-Scholes formula are commonly used to determine the fair value of derivatives based on these inputs, although market conditions can lead to deviations from theoretical values.",
      "Market sentiment and supply-demand dynamics also play a role, as investor perceptions and trading volumes can cause derivative prices to diverge from model predictions."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "The pricing of derivatives, such as options and futures, is influenced by factors including the underlying asset's price, volatility, time to expiration, and prevailing interest rates.",
        "Mathematical models like the Black-Scholes formula are commonly used to determine the fair value of derivatives based on these inputs, although market conditions can lead to deviations from theoretical values.",
        "Market sentiment and supply-demand dynamics also play a role, as investor perceptions and trading volumes can cause derivative prices to diverge from model predictions."
      ]
    }
  },
  {
    "question": "How does investor sentiment drive market trends?",
    "retrieved_chunks": [
      "Investor sentiment, driven by factors such as economic news, earnings reports, and global events, can significantly influence market trends, often leading to herd behavior among investors.",
      "Positive sentiment can fuel market rallies, while negative sentiment may trigger sell-offs, regardless of underlying fundamental values.",
      "Surveys and sentiment indices are frequently used by analysts to gauge the mood of the market, providing insights into potential turning points and the strength of market movements."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Investor sentiment, driven by factors such as economic news, earnings reports, and global events, can significantly influence market trends, often leading to herd behavior among investors.",
        "Positive sentiment can fuel market rallies, while negative sentiment may trigger sell-offs, regardless of underlying fundamental values.",
        "Surveys and sentiment indices are frequently used by analysts to gauge the mood of the market, providing insights into potential turning points and the strength of market movements."
      ]
    }
  },
  {
    "question": "What role do hedge funds play in the financial ecosystem?",
    "retrieved_chunks": [
      "Hedge funds are investment vehicles that employ a variety of strategies, including long-short equity, arbitrage, and global macro, to generate returns for their investors.",
      "These funds often operate with a high degree of flexibility and can take both long and short positions, which can contribute to market efficiency by identifying mispriced assets.",
      "However, hedge funds can also introduce systemic risks due to their use of leverage and complex investment strategies, necessitating careful regulatory oversight."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Hedge funds are investment vehicles that employ a variety of strategies, including long-short equity, arbitrage, and global macro, to generate returns for their investors.",
        "These funds often operate with a high degree of flexibility and can take both long and short positions, which can contribute to market efficiency by identifying mispriced assets.",
        "However, hedge funds can also introduce systemic risks due to their use of leverage and complex investment strategies, necessitating careful regulatory oversight."
      ]
    }
  },
  {
    "question": "How is risk measured in portfolio management?",
    "retrieved_chunks": [
      "Risk in portfolio management is commonly measured using metrics such as standard deviation, beta, and Value at Risk (VaR), which help quantify the potential for loss in a portfolio.",
      "Diversification is a key strategy for mitigating risk, as it spreads investments across various asset classes and reduces exposure to any single source of volatility.",
      "Advanced risk management techniques also include stress testing and scenario analysis to assess how a portfolio might perform under adverse market conditions."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Risk in portfolio management is commonly measured using metrics such as standard deviation, beta, and Value at Risk (VaR), which help quantify the potential for loss in a portfolio.",
        "Diversification is a key strategy for mitigating risk, as it spreads investments across various asset classes and reduces exposure to any single source of volatility.",
        "Advanced risk management techniques also include stress testing and scenario analysis to assess how a portfolio might perform under adverse market conditions."
      ]
    }
  },
  {
    "question": "What are the implications of a flattening yield curve?",
    "retrieved_chunks": [
      "A flattening yield curve occurs when the difference between short-term and long-term interest rates narrows, which can be an indicator of changing economic conditions.",
      "Investors often interpret a flattening yield curve as a signal that economic growth may be slowing, potentially leading to reduced profitability in sectors such as banking.",
      "However, some economists argue that a flattening curve can also result from central bank policies and does not always predict an imminent recession."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "A flattening yield curve occurs when the difference between short-term and long-term interest rates narrows, which can be an indicator of changing economic conditions.",
        "Investors often interpret a flattening yield curve as a signal that economic growth may be slowing, potentially leading to reduced profitability in sectors such as banking.",
        "However, some economists argue that a flattening curve can also result from central bank policies and does not always predict an imminent recession."
      ]
    }
  },
  {
    "question": "How do sovereign wealth funds impact global markets?",
    "retrieved_chunks": [
      "Sovereign wealth funds (SWFs) are state-owned investment funds that manage surplus revenues, often from natural resources, and invest in a wide range of assets globally.",
      "SWFs can have a stabilizing effect on global markets by providing long-term capital and reducing volatility, as their investment strategies are typically less reactive to short-term market fluctuations.",
      "Nevertheless, the massive scale of some SWFs can also lead to concerns about market influence and potential conflicts of interest in domestic and international investments."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Sovereign wealth funds (SWFs) are state-owned investment funds that manage surplus revenues, often from natural resources, and invest in a wide range of assets globally.",
        "SWFs can have a stabilizing effect on global markets by providing long-term capital and reducing volatility, as their investment strategies are typically less reactive to short-term market fluctuations.",
        "Nevertheless, the massive scale of some SWFs can also lead to concerns about market influence and potential conflicts of interest in domestic and international investments."
      ]
    }
  },
  {
    "question": "What are the effects of currency devaluation on domestic inflation?",
    "retrieved_chunks": [
      "Currency devaluation reduces the value of a country's currency relative to others, which can lead to higher import prices and contribute to domestic inflation.",
      "As the cost of imported goods rises, consumers may face increased prices, thereby reducing purchasing power and potentially triggering broader inflationary pressures across the economy.",
      "However, a devalued currency can also make exports more competitive, which might partially offset inflationary effects by stimulating domestic production."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Currency devaluation reduces the value of a country's currency relative to others, which can lead to higher import prices and contribute to domestic inflation.",
        "As the cost of imported goods rises, consumers may face increased prices, thereby reducing purchasing power and potentially triggering broader inflationary pressures across the economy.",
        "However, a devalued currency can also make exports more competitive, which might partially offset inflationary effects by stimulating domestic production."
      ]
    }
  },
  {
    "question": "How does the time value of money affect investment decisions?",
    "retrieved_chunks": [
      "The time value of money is a financial concept that recognizes the idea that a sum of money today is worth more than the same sum in the future due to its earning potential.",
      "Investment decisions often rely on discounting future cash flows to their present value, enabling comparisons between projects with different timelines and risk profiles.",
      "Understanding the time value of money is critical in capital budgeting and helps investors evaluate the trade-offs between immediate returns and long-term gains."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "The time value of money is a financial concept that recognizes the idea that a sum of money today is worth more than the same sum in the future due to its earning potential.",
        "Investment decisions often rely on discounting future cash flows to their present value, enabling comparisons between projects with different timelines and risk profiles.",
        "Understanding the time value of money is critical in capital budgeting and helps investors evaluate the trade-offs between immediate returns and long-term gains."
      ]
    }
  },
  {
    "question": "What is the significance of the Federal Reserve's balance sheet?",
    "retrieved_chunks": [
      "The Federal Reserve's balance sheet provides insights into its monetary policy stance, reflecting the assets it has purchased and the liabilities it has incurred through various policy measures.",
      "A large balance sheet, often the result of quantitative easing, indicates significant central bank intervention in the financial markets, which can have long-term implications for liquidity and interest rates.",
      "Critics argue that an expanded balance sheet may pose risks for financial stability, while supporters contend that it is a necessary tool for managing economic downturns."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "The Federal Reserve's balance sheet provides insights into its monetary policy stance, reflecting the assets it has purchased and the liabilities it has incurred through various policy measures.",
        "A large balance sheet, often the result of quantitative easing, indicates significant central bank intervention in the financial markets, which can have long-term implications for liquidity and interest rates.",
        "Critics argue that an expanded balance sheet may pose risks for financial stability, while supporters contend that it is a necessary tool for managing economic downturns."
      ]
    }
  },
  {
    "question": "How do financial derivatives contribute to risk management?",
    "retrieved_chunks": [
      "Financial derivatives, including options, futures, and swaps, are instruments that allow investors to hedge against various types of risk, such as market volatility or interest rate fluctuations.",
      "By using derivatives, companies and investors can create strategies to offset potential losses, effectively transferring risk from one party to another.",
      "While derivatives can provide valuable risk management benefits, they also introduce complexities and potential for significant losses if not managed properly."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Financial derivatives, including options, futures, and swaps, are instruments that allow investors to hedge against various types of risk, such as market volatility or interest rate fluctuations.",
        "By using derivatives, companies and investors can create strategies to offset potential losses, effectively transferring risk from one party to another.",
        "While derivatives can provide valuable risk management benefits, they also introduce complexities and potential for significant losses if not managed properly."
      ]
    }
  },
  {
    "question": "What role does technological innovation play in modern banking?",
    "retrieved_chunks": [
      "Technological innovation in banking has revolutionized how financial services are delivered, from mobile banking apps to advanced cybersecurity measures.",
      "Innovations such as blockchain and artificial intelligence are transforming traditional banking operations by enhancing efficiency and reducing operational risks.",
      "However, the rapid pace of technological change also poses challenges for regulatory frameworks and legacy systems, requiring continuous adaptation from financial institutions."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Technological innovation in banking has revolutionized how financial services are delivered, from mobile banking apps to advanced cybersecurity measures.",
        "Innovations such as blockchain and artificial intelligence are transforming traditional banking operations by enhancing efficiency and reducing operational risks.",
        "However, the rapid pace of technological change also poses challenges for regulatory frameworks and legacy systems, requiring continuous adaptation from financial institutions."
      ]
    }
  },
  {
    "question": "How does short selling influence market dynamics?",
    "retrieved_chunks": [
      "Short selling involves selling borrowed stocks with the expectation that their price will decline, allowing investors to buy them back at a lower cost and profit from the difference.",
      "This practice can contribute to market efficiency by revealing overvalued stocks, but it can also increase market volatility if conducted on a large scale.",
      "Critics argue that short selling may exacerbate downward spirals in stock prices during market downturns, while proponents view it as a mechanism for correcting mispricings."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Short selling involves selling borrowed stocks with the expectation that their price will decline, allowing investors to buy them back at a lower cost and profit from the difference.",
        "This practice can contribute to market efficiency by revealing overvalued stocks, but it can also increase market volatility if conducted on a large scale.",
        "Critics argue that short selling may exacerbate downward spirals in stock prices during market downturns, while proponents view it as a mechanism for correcting mispricings."
      ]
    }
  },
  {
    "question": "What are the challenges of valuing intangible assets?",
    "retrieved_chunks": [
      "Valuing intangible assets such as intellectual property, brand reputation, and customer relationships is challenging due to their subjective nature and lack of physical presence.",
      "Traditional valuation methods may not adequately capture the true economic value of these assets, leading to potential discrepancies in financial reporting.",
      "Innovative approaches, including market-based and income-based valuation techniques, are increasingly being used to assess intangible assets more accurately."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Valuing intangible assets such as intellectual property, brand reputation, and customer relationships is challenging due to their subjective nature and lack of physical presence.",
        "Traditional valuation methods may not adequately capture the true economic value of these assets, leading to potential discrepancies in financial reporting.",
        "Innovative approaches, including market-based and income-based valuation techniques, are increasingly being used to assess intangible assets more accurately."
      ]
    }
  },
  {
    "question": "How do environmental, social, and governance (ESG) factors impact investment strategies?",
    "retrieved_chunks": [
      "ESG factors have become increasingly important in investment strategies, with many investors considering a company's environmental impact, social responsibilities, and governance practices when making decisions.",
      "Incorporating ESG criteria can help identify companies that are well-positioned for long-term sustainability, potentially leading to better risk-adjusted returns.",
      "However, the integration of ESG factors also poses challenges, as standardized metrics and reliable data are still evolving, making it difficult to fully assess their impact on financial performance."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "ESG factors have become increasingly important in investment strategies, with many investors considering a company's environmental impact, social responsibilities, and governance practices when making decisions.",
        "Incorporating ESG criteria can help identify companies that are well-positioned for long-term sustainability, potentially leading to better risk-adjusted returns.",
        "However, the integration of ESG factors also poses challenges, as standardized metrics and reliable data are still evolving, making it difficult to fully assess their impact on financial performance."
      ]
    }
  },
  {
    "question": "What are the determinants of capital structure in firms?",
    "retrieved_chunks": [
      "A firm's capital structure is determined by a mix of debt and equity financing, with decisions influenced by factors such as tax considerations, cost of capital, and market conditions.",
      "The optimal capital structure balances the benefits of debt, such as tax shields, against the risks of financial distress and higher interest costs.",
      "Managerial preferences and industry-specific dynamics also play significant roles in shaping a company's financing decisions and overall capital structure."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "A firm's capital structure is determined by a mix of debt and equity financing, with decisions influenced by factors such as tax considerations, cost of capital, and market conditions.",
        "The optimal capital structure balances the benefits of debt, such as tax shields, against the risks of financial distress and higher interest costs.",
        "Managerial preferences and industry-specific dynamics also play significant roles in shaping a company's financing decisions and overall capital structure."
      ]
    }
  },
  {
    "question": "How does private equity differ from venture capital?",
    "retrieved_chunks": [
      "Private equity typically involves investing in established companies with the aim of improving operational efficiency and profitability, often through restructuring or strategic acquisitions.",
      "Venture capital, on the other hand, focuses on early-stage startups and innovative companies with high growth potential, accepting higher risks in exchange for substantial returns.",
      "While both forms of investment provide capital in exchange for equity, they differ in terms of investment stage, risk profile, and the level of involvement in company management."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Private equity typically involves investing in established companies with the aim of improving operational efficiency and profitability, often through restructuring or strategic acquisitions.",
        "Venture capital, on the other hand, focuses on early-stage startups and innovative companies with high growth potential, accepting higher risks in exchange for substantial returns.",
        "While both forms of investment provide capital in exchange for equity, they differ in terms of investment stage, risk profile, and the level of involvement in company management."
      ]
    }
  },
  {
    "question": "What is the impact of sovereign debt crises on global economies?",
    "retrieved_chunks": [
      "Sovereign debt crises occur when a country is unable to meet its debt obligations, leading to potential defaults and a loss of investor confidence.",
      "Such crises can trigger global financial instability as investors reassess risk and withdraw capital from affected regions, impacting currency values and international trade.",
      "The ripple effects of a sovereign debt crisis can extend to other economies, prompting coordinated responses from international financial institutions and central banks."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Sovereign debt crises occur when a country is unable to meet its debt obligations, leading to potential defaults and a loss of investor confidence.",
        "Such crises can trigger global financial instability as investors reassess risk and withdraw capital from affected regions, impacting currency values and international trade.",
        "The ripple effects of a sovereign debt crisis can extend to other economies, prompting coordinated responses from international financial institutions and central banks."
      ]
    }
  },
  {
    "question": "How do consumer confidence indices affect market performance?",
    "retrieved_chunks": [
      "Consumer confidence indices measure the optimism or pessimism of consumers regarding their financial situation and the overall state of the economy.",
      "High consumer confidence often correlates with increased spending and economic growth, which can drive market performance upward.",
      "Conversely, low consumer confidence may signal economic uncertainty, leading to reduced spending and potentially triggering market downturns."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Consumer confidence indices measure the optimism or pessimism of consumers regarding their financial situation and the overall state of the economy.",
        "High consumer confidence often correlates with increased spending and economic growth, which can drive market performance upward.",
        "Conversely, low consumer confidence may signal economic uncertainty, leading to reduced spending and potentially triggering market downturns."
      ]
    }
  },
  {
    "question": "What role does blockchain technology play in financial transactions?",
    "retrieved_chunks": [
      "Blockchain technology provides a decentralized and secure method for recording transactions, reducing the need for intermediaries in financial operations.",
      "Its use in financial transactions enhances transparency, minimizes fraud, and streamlines settlement processes by providing a single, immutable ledger.",
      "While blockchain has significant potential to transform traditional banking systems, challenges such as scalability and regulatory uncertainty remain obstacles to its widespread adoption."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Blockchain technology provides a decentralized and secure method for recording transactions, reducing the need for intermediaries in financial operations.",
        "Its use in financial transactions enhances transparency, minimizes fraud, and streamlines settlement processes by providing a single, immutable ledger.",
        "While blockchain has significant potential to transform traditional banking systems, challenges such as scalability and regulatory uncertainty remain obstacles to its widespread adoption."
      ]
    }
  },
  {
    "question": "How do derivatives markets help in hedging financial risks?",
    "retrieved_chunks": [
      "Derivatives markets allow investors to hedge against various risks by taking positions that offset potential losses in their primary investments.",
      "Instruments like options, futures, and swaps enable companies to manage exposures to fluctuations in interest rates, commodity prices, and foreign exchange rates.",
      "Effective hedging through derivatives can stabilize cash flows and protect against adverse market movements, although it requires sophisticated risk management techniques."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Derivatives markets allow investors to hedge against various risks by taking positions that offset potential losses in their primary investments.",
        "Instruments like options, futures, and swaps enable companies to manage exposures to fluctuations in interest rates, commodity prices, and foreign exchange rates.",
        "Effective hedging through derivatives can stabilize cash flows and protect against adverse market movements, although it requires sophisticated risk management techniques."
      ]
    }
  },
  {
    "question": "What are the effects of a high debt-to-equity ratio on a company's financial health?",
    "retrieved_chunks": [
      "A high debt-to-equity ratio indicates that a company is heavily reliant on debt financing, which can amplify both profits and losses depending on market conditions.",
      "This high leverage increases the risk of financial distress, as companies must generate sufficient cash flow to service their debt obligations even during downturns.",
      "Investors closely monitor debt-to-equity ratios to assess a company's risk profile, with excessive debt often leading to lower credit ratings and higher borrowing costs."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "A high debt-to-equity ratio indicates that a company is heavily reliant on debt financing, which can amplify both profits and losses depending on market conditions.",
        "This high leverage increases the risk of financial distress, as companies must generate sufficient cash flow to service their debt obligations even during downturns.",
        "Investors closely monitor debt-to-equity ratios to assess a company's risk profile, with excessive debt often leading to lower credit ratings and higher borrowing costs."
      ]
    }
  },
  {
    "question": "How does the liquidity trap affect monetary policy effectiveness?",
    "retrieved_chunks": [
      "A liquidity trap occurs when interest rates are already very low, rendering monetary policy ineffective because consumers and investors prefer holding cash over low-yielding assets.",
      "In such an environment, traditional monetary tools like rate cuts have little impact on stimulating economic activity, as demand for loans remains subdued.",
      "Economists argue that unconventional measures, such as quantitative easing, may be required to overcome the constraints imposed by a liquidity trap."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "A liquidity trap occurs when interest rates are already very low, rendering monetary policy ineffective because consumers and investors prefer holding cash over low-yielding assets.",
        "In such an environment, traditional monetary tools like rate cuts have little impact on stimulating economic activity, as demand for loans remains subdued.",
        "Economists argue that unconventional measures, such as quantitative easing, may be required to overcome the constraints imposed by a liquidity trap."
      ]
    }
  },
  {
    "question": "What are the key metrics used in evaluating a company's performance?",
    "retrieved_chunks": [
      "Key performance metrics for companies include earnings per share (EPS), return on equity (ROE), and profit margins, which provide insights into profitability and operational efficiency.",
      "Other important metrics include revenue growth, cash flow, and debt-to-equity ratios, all of which help investors gauge the financial health of a business.",
      "Industry-specific benchmarks also play a role in performance evaluation, as different sectors may prioritize certain metrics over others for a more accurate assessment."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Key performance metrics for companies include earnings per share (EPS), return on equity (ROE), and profit margins, which provide insights into profitability and operational efficiency.",
        "Other important metrics include revenue growth, cash flow, and debt-to-equity ratios, all of which help investors gauge the financial health of a business.",
        "Industry-specific benchmarks also play a role in performance evaluation, as different sectors may prioritize certain metrics over others for a more accurate assessment."
      ]
    }
  },
  {
    "question": "How do fiscal deficits influence long-term economic growth?",
    "retrieved_chunks": [
      "Fiscal deficits occur when a government's expenditures exceed its revenues, leading to borrowing to finance the gap.",
      "Persistent fiscal deficits can crowd out private investment and may lead to higher interest rates, potentially dampening long-term economic growth.",
      "However, in times of economic downturn, deficit spending can stimulate growth by injecting necessary funds into the economy, though the long-term implications depend on how the borrowed funds are utilized."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Fiscal deficits occur when a government's expenditures exceed its revenues, leading to borrowing to finance the gap.",
        "Persistent fiscal deficits can crowd out private investment and may lead to higher interest rates, potentially dampening long-term economic growth.",
        "However, in times of economic downturn, deficit spending can stimulate growth by injecting necessary funds into the economy, though the long-term implications depend on how the borrowed funds are utilized."
      ]
    }
  },
  {
    "question": "What is the role of central banks in crisis management?",
    "retrieved_chunks": [
      "Central banks play a critical role in managing financial crises by providing liquidity, setting interest rates, and acting as lenders of last resort to stabilize the banking system.",
      "During crises, measures such as emergency lending facilities and asset purchase programs are deployed to restore confidence and ensure the smooth functioning of financial markets.",
      "The effectiveness of central banks in crisis management is often subject to debate, with some arguing that their actions can lead to moral hazard and unintended long-term consequences."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Central banks play a critical role in managing financial crises by providing liquidity, setting interest rates, and acting as lenders of last resort to stabilize the banking system.",
        "During crises, measures such as emergency lending facilities and asset purchase programs are deployed to restore confidence and ensure the smooth functioning of financial markets.",
        "The effectiveness of central banks in crisis management is often subject to debate, with some arguing that their actions can lead to moral hazard and unintended long-term consequences."
      ]
    }
  },
  {
    "question": "How do fluctuations in oil prices impact global economies?",
    "retrieved_chunks": [
      "Oil price fluctuations can have a significant impact on global economies, affecting everything from inflation and trade balances to energy costs and consumer spending.",
      "Countries that are major oil exporters may experience economic booms during periods of high prices, while oil-importing nations could face increased production costs and reduced consumer spending.",
      "Volatile oil prices also influence investment decisions in the energy sector and can lead to shifts in geopolitical dynamics as nations adjust their economic strategies."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Oil price fluctuations can have a significant impact on global economies, affecting everything from inflation and trade balances to energy costs and consumer spending.",
        "Countries that are major oil exporters may experience economic booms during periods of high prices, while oil-importing nations could face increased production costs and reduced consumer spending.",
        "Volatile oil prices also influence investment decisions in the energy sector and can lead to shifts in geopolitical dynamics as nations adjust their economic strategies."
      ]
    }
  },
  {
    "question": "What is the importance of transparency in financial reporting?",
    "retrieved_chunks": [
      "Transparency in financial reporting ensures that investors and stakeholders have access to accurate and comprehensive information, which is essential for making informed decisions.",
      "Clear and reliable financial disclosures help build trust in the markets and facilitate efficient capital allocation, reducing the risk of fraud and mismanagement.",
      "Regulatory frameworks and auditing standards are designed to enhance transparency, although challenges remain in achieving complete and timely disclosure in all financial sectors."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Transparency in financial reporting ensures that investors and stakeholders have access to accurate and comprehensive information, which is essential for making informed decisions.",
        "Clear and reliable financial disclosures help build trust in the markets and facilitate efficient capital allocation, reducing the risk of fraud and mismanagement.",
        "Regulatory frameworks and auditing standards are designed to enhance transparency, although challenges remain in achieving complete and timely disclosure in all financial sectors."
      ]
    }
  },
  {
    "question": "How do exchange-traded funds (ETFs) differ from mutual funds?",
    "retrieved_chunks": [
      "ETFs are traded on stock exchanges like individual stocks, offering intraday liquidity and typically lower expense ratios compared to mutual funds.",
      "Mutual funds, on the other hand, are priced at the end of the trading day and often require minimum investments, with active management driving their performance.",
      "Both ETFs and mutual funds offer diversification benefits, but ETFs provide more flexibility for investors who seek to capitalize on market movements throughout the trading day."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "ETFs are traded on stock exchanges like individual stocks, offering intraday liquidity and typically lower expense ratios compared to mutual funds.",
        "Mutual funds, on the other hand, are priced at the end of the trading day and often require minimum investments, with active management driving their performance.",
        "Both ETFs and mutual funds offer diversification benefits, but ETFs provide more flexibility for investors who seek to capitalize on market movements throughout the trading day."
      ]
    }
  },
  {
    "question": "What are the risks and rewards of investing in cryptocurrencies?",
    "retrieved_chunks": [
      "Investing in cryptocurrencies can offer high rewards due to significant price volatility and the potential for substantial capital gains, but these opportunities come with high risk.",
      "Cryptocurrencies operate in a largely unregulated environment, which can lead to issues such as market manipulation, security breaches, and liquidity challenges.",
      "The underlying blockchain technology presents both innovative advantages and uncertainties, as regulatory frameworks and market acceptance continue to evolve."
    ],
    "final_answer": {
      "useful_count": 3,
      "ordered_chunks": [
        "Investing in cryptocurrencies can offer high rewards due to significant price volatility and the potential for substantial capital gains, but these opportunities come with high risk.",
        "Cryptocurrencies operate in a largely unregulated environment, which can lead to issues such as market manipulation, security breaches, and liquidity challenges.",
        "The underlying blockchain technology presents both innovative advantages and uncertainties, as regulatory frameworks and market acceptance continue to evolve."
      ]
    }
  },
  {
    "question": "How does a rising federal funds rate impact consumer loans?",
    "retrieved_chunks": [
      "A rising federal funds rate typically results in higher interest rates on consumer loans, increasing borrowing costs and potentially reducing consumer spending.",
      "During economic booms, banks often increase their credit lines, making more funds available to consumers.",
      "Investment in emerging markets can be highly volatile due to political instability."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "A rising federal funds rate typically results in higher interest rates on consumer loans, increasing borrowing costs and potentially reducing consumer spending."
      ]
    }
  },
  {
    "question": "What is the role of credit default swaps in risk management?",
    "retrieved_chunks": [
      "Credit default swaps (CDS) are financial derivatives used to transfer credit risk, allowing one party to hedge against defaults.",
      "They can also be used speculatively, but their pricing does not directly relate to interest rate movements.",
      "Some investors use equity options to manage their portfolio risk."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Credit default swaps (CDS) are financial derivatives used to transfer credit risk, allowing one party to hedge against defaults."
      ]
    }
  },
  {
    "question": "How does fiscal stimulus influence short-term economic growth?",
    "retrieved_chunks": [
      "Fiscal stimulus, such as increased government spending, can provide an immediate boost to short-term economic growth by increasing aggregate demand.",
      "Monetary policy often works independently of fiscal policy in controlling inflation.",
      "Interest rate adjustments by central banks have a long-term impact on capital formation."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Fiscal stimulus, such as increased government spending, can provide an immediate boost to short-term economic growth by increasing aggregate demand."
      ]
    }
  },
  {
    "question": "What is the effect of corporate tax cuts on business investments?",
    "retrieved_chunks": [
      "Corporate tax cuts can increase after-tax profits, thereby encouraging businesses to invest more in expansion and capital projects.",
      "Dividend policies of companies sometimes reflect changes in tax structures.",
      "The valuation of assets in accounting is subject to various depreciation methods."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Corporate tax cuts can increase after-tax profits, thereby encouraging businesses to invest more in expansion and capital projects."
      ]
    }
  },
  {
    "question": "How does consumer confidence impact retail sales?",
    "retrieved_chunks": [
      "High consumer confidence often translates into increased retail sales as consumers are more willing to spend money.",
      "Retail sales are also influenced by seasonal factors and holiday promotions.",
      "Central bank policies can indirectly affect consumer behavior through interest rate changes."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "High consumer confidence often translates into increased retail sales as consumers are more willing to spend money."
      ]
    }
  },
  {
    "question": "What is the impact of currency appreciation on export competitiveness?",
    "retrieved_chunks": [
      "Currency appreciation makes exports more expensive, reducing a country's competitiveness in international markets.",
      "The balance of payments can be influenced by fluctuations in currency values.",
      "Fiscal deficits have a long-term effect on government borrowing costs."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Currency appreciation makes exports more expensive, reducing a country's competitiveness in international markets."
      ]
    }
  },
  {
    "question": "How does increased bank capital improve financial stability?",
    "retrieved_chunks": [
      "Higher bank capital provides a cushion against potential losses, thereby enhancing financial stability in the banking sector.",
      "Technological innovations in banking have changed the way services are delivered.",
      "Consumer behavior in retail markets is driven by advertising strategies."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Higher bank capital provides a cushion against potential losses, thereby enhancing financial stability in the banking sector."
      ]
    }
  },
  {
    "question": "What is the role of the yield curve in predicting recessions?",
    "retrieved_chunks": [
      "An inverted yield curve, where short-term rates exceed long-term rates, is often considered a predictor of upcoming recessions.",
      "Commodity prices can sometimes influence investor sentiment in stock markets.",
      "Corporate earnings are a key driver of stock valuations."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "An inverted yield curve, where short-term rates exceed long-term rates, is often considered a predictor of upcoming recessions."
      ]
    }
  },
  {
    "question": "How does market speculation affect commodity prices?",
    "retrieved_chunks": [
      "Market speculation can lead to volatile commodity prices as investors buy and sell based on future price expectations rather than current supply and demand fundamentals.",
      "Government policies may affect commodity production quotas.",
      "Retail inflation indexes are used to measure consumer price changes."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Market speculation can lead to volatile commodity prices as investors buy and sell based on future price expectations rather than current supply and demand fundamentals."
      ]
    }
  },
  {
    "question": "What is the significance of operating leverage in a company's earnings?",
    "retrieved_chunks": [
      "Operating leverage measures the extent to which a company uses fixed costs in its operations, affecting the variability of its earnings.",
      "Market liquidity is important for facilitating quick trades.",
      "Bond maturities are an important consideration for investors."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Operating leverage measures the extent to which a company uses fixed costs in its operations, affecting the variability of its earnings."
      ]
    }
  },
  {
    "question": "How do interest rate swaps function in financial markets?",
    "retrieved_chunks": [
      "Interest rate swaps allow parties to exchange fixed and floating rate payments, thereby managing exposure to fluctuations in interest rates.",
      "Credit ratings can impact the cost of borrowing for companies.",
      "Equity markets and bond markets often respond differently to economic news."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Interest rate swaps allow parties to exchange fixed and floating rate payments, thereby managing exposure to fluctuations in interest rates."
      ]
    }
  },
  {
    "question": "What impact does regulatory reform have on financial institutions?",
    "retrieved_chunks": [
      "Regulatory reform can lead to increased compliance costs for financial institutions, potentially impacting their profitability.",
      "Technological advancements are reshaping the way consumers access banking services.",
      "Retail investors are becoming more active in the stock market."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Regulatory reform can lead to increased compliance costs for financial institutions, potentially impacting their profitability."
      ]
    }
  },
  {
    "question": "How do changes in reserve requirements affect bank lending?",
    "retrieved_chunks": [
      "An increase in reserve requirements typically reduces the amount of money banks can lend, thereby contracting credit availability.",
      "Fiscal policies have a direct effect on consumer confidence.",
      "Investor sentiment often drives stock market trends."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "An increase in reserve requirements typically reduces the amount of money banks can lend, thereby contracting credit availability."
      ]
    }
  },
  {
    "question": "What is the influence of market sentiment on asset bubbles?",
    "retrieved_chunks": [
      "Excessive market optimism can inflate asset prices beyond their intrinsic value, contributing to the formation of bubbles.",
      "Technological changes in the financial sector can improve trading efficiency.",
      "Central bank communications can affect short-term market volatility."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Excessive market optimism can inflate asset prices beyond their intrinsic value, contributing to the formation of bubbles."
      ]
    }
  },
  {
    "question": "How does cost of capital influence corporate investment decisions?",
    "retrieved_chunks": [
      "A lower cost of capital makes it cheaper for companies to finance new projects, thereby encouraging more investment.",
      "Investment strategies vary significantly between sectors.",
      "Market trends often shift with changes in consumer behavior."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "A lower cost of capital makes it cheaper for companies to finance new projects, thereby encouraging more investment."
      ]
    }
  },
  {
    "question": "What is the effect of leverage on small business growth?",
    "retrieved_chunks": [
      "For small businesses, moderate leverage can facilitate growth by providing necessary funds, but excessive leverage increases the risk of insolvency.",
      "Consumer credit scores can impact loan approval rates.",
      "The diversification of asset portfolios helps mitigate risk."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "For small businesses, moderate leverage can facilitate growth by providing necessary funds, but excessive leverage increases the risk of insolvency."
      ]
    }
  },
  {
    "question": "How do pension funds influence capital markets?",
    "retrieved_chunks": [
      "Pension funds are significant institutional investors whose large-scale investments can influence capital market trends and asset valuations.",
      "Retail investment in tech stocks has surged in recent years.",
      "Commodity trading is subject to seasonal fluctuations."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Pension funds are significant institutional investors whose large-scale investments can influence capital market trends and asset valuations."
      ]
    }
  },
  {
    "question": "What is the relationship between interest rates and savings rates?",
    "retrieved_chunks": [
      "Higher interest rates generally encourage savings by offering better returns on deposits, whereas lower rates can lead to reduced savings.",
      "Stock market indices are affected by corporate performance.",
      "Government spending can have mixed effects on inflation."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Higher interest rates generally encourage savings by offering better returns on deposits, whereas lower rates can lead to reduced savings."
      ]
    }
  },
  {
    "question": "How does economic uncertainty impact capital investment?",
    "retrieved_chunks": [
      "Economic uncertainty tends to delay capital investment as companies adopt a wait-and-see approach to avoid committing resources in volatile conditions.",
      "Asset allocation strategies often vary by investor risk tolerance.",
      "The role of emerging markets in global trade is significant."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "Economic uncertainty tends to delay capital investment as companies adopt a wait-and-see approach to avoid committing resources in volatile conditions."
      ]
    }
  },
  {
    "question": "What factors contribute to a bank run?",
    "retrieved_chunks": [
      "A bank run can occur when depositors lose confidence in the bank's solvency and rush to withdraw their funds, triggering liquidity issues.",
      "International trade policies can affect national economic stability.",
      "Corporate earnings reports are closely watched by investors."
    ],
    "final_answer": {
      "useful_count": 1,
      "ordered_chunks": [
        "A bank run can occur when depositors lose confidence in the bank's solvency and rush to withdraw their funds, triggering liquidity issues."
      ]
    }
  },
  {
    "question": "How does quantitative tightening affect market liquidity?",
    "retrieved_chunks": [
      "Quantitative tightening involves the gradual reduction of a central bank's balance sheet, which can lead to tighter liquidity conditions in financial markets.",
      "This policy shift often results in higher interest rates and reduced credit availability, impacting both borrowers and investors.",
      "Fiscal stimulus measures are typically used to boost economic growth during recessions."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Quantitative tightening involves the gradual reduction of a central bank's balance sheet, which can lead to tighter liquidity conditions in financial markets.",
        "This policy shift often results in higher interest rates and reduced credit availability, impacting both borrowers and investors."
      ]
    }
  },
  {
    "question": "What impact do rising energy prices have on inflation?",
    "retrieved_chunks": [
      "Rising energy prices can contribute to inflation by increasing the cost of production and transportation, thereby raising consumer prices.",
      "Higher energy prices may also shift consumer spending from discretionary items to essential goods.",
      "Interest rate changes have a direct impact on bond yields."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Rising energy prices can contribute to inflation by increasing the cost of production and transportation, thereby raising consumer prices.",
        "Higher energy prices may also shift consumer spending from discretionary items to essential goods."
      ]
    }
  },
  {
    "question": "How do macroeconomic indicators influence foreign investment?",
    "retrieved_chunks": [
      "Strong macroeconomic indicators, such as GDP growth and low unemployment, can attract foreign investment by signaling a healthy economic environment.",
      "Inflation rates and trade balances also play a critical role in shaping investor confidence in a country's economic prospects.",
      "Corporate governance practices are more relevant to internal management than to foreign investment decisions."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Strong macroeconomic indicators, such as GDP growth and low unemployment, can attract foreign investment by signaling a healthy economic environment.",
        "Inflation rates and trade balances also play a critical role in shaping investor confidence in a country's economic prospects."
      ]
    }
  },
  {
    "question": "What role does investor sentiment play in market corrections?",
    "retrieved_chunks": [
      "Investor sentiment can accelerate market corrections when negative news or panic leads to a rapid sell-off.",
      "It often acts as a self-reinforcing mechanism, where declining prices further dampen sentiment and drive further selling.",
      "The liquidity of a market is unrelated to sentiment-driven corrections."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Investor sentiment can accelerate market corrections when negative news or panic leads to a rapid sell-off.",
        "It often acts as a self-reinforcing mechanism, where declining prices further dampen sentiment and drive further selling."
      ]
    }
  },
  {
    "question": "How do government subsidies impact renewable energy investments?",
    "retrieved_chunks": [
      "Government subsidies can lower the effective cost of renewable energy projects, thereby encouraging increased investment in the sector.",
      "Subsidies also help mitigate the initial high capital costs associated with renewable technologies.",
      "The effect of interest rate changes on bond markets is a separate issue."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Government subsidies can lower the effective cost of renewable energy projects, thereby encouraging increased investment in the sector.",
        "Subsidies also help mitigate the initial high capital costs associated with renewable technologies."
      ]
    }
  },
  {
    "question": "What is the effect of deregulation on financial innovation?",
    "retrieved_chunks": [
      "Deregulation can spur financial innovation by reducing bureaucratic hurdles, allowing institutions to develop new products and services.",
      "However, it may also increase systemic risks if new financial instruments are not properly monitored.",
      "Consumer credit trends are not directly impacted by deregulation in the short term."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Deregulation can spur financial innovation by reducing bureaucratic hurdles, allowing institutions to develop new products and services.",
        "However, it may also increase systemic risks if new financial instruments are not properly monitored."
      ]
    }
  },
  {
    "question": "How do trade tariffs affect domestic manufacturing sectors?",
    "retrieved_chunks": [
      "Trade tariffs can protect domestic manufacturing by making imported goods more expensive, thereby encouraging consumers to buy locally produced products.",
      "They may also lead to retaliatory measures from trade partners, affecting overall economic relations.",
      "Central bank policies are primarily concerned with monetary conditions rather than trade disputes."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Trade tariffs can protect domestic manufacturing by making imported goods more expensive, thereby encouraging consumers to buy locally produced products.",
        "They may also lead to retaliatory measures from trade partners, affecting overall economic relations."
      ]
    }
  },
  {
    "question": "What influence does digital currency adoption have on traditional banking?",
    "retrieved_chunks": [
      "Digital currency adoption can pressure traditional banks to modernize their payment systems and improve security measures.",
      "It may also reduce transaction costs and increase the speed of cross-border payments, affecting conventional banking operations.",
      "Corporate restructuring strategies are not directly related to digital currency trends."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Digital currency adoption can pressure traditional banks to modernize their payment systems and improve security measures.",
        "It may also reduce transaction costs and increase the speed of cross-border payments, affecting conventional banking operations."
      ]
    }
  },
  {
    "question": "How do changes in consumer debt levels affect economic growth?",
    "retrieved_chunks": [
      "Increased consumer debt levels can constrain economic growth by limiting disposable income and reducing spending.",
      "High levels of indebtedness also raise the risk of defaults, which can have broader economic implications.",
      "Investment in real estate markets is influenced by different factors."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Increased consumer debt levels can constrain economic growth by limiting disposable income and reducing spending.",
        "High levels of indebtedness also raise the risk of defaults, which can have broader economic implications."
      ]
    }
  },
  {
    "question": "What is the impact of fiscal austerity on public sector employment?",
    "retrieved_chunks": [
      "Fiscal austerity measures typically result in reduced public sector spending, which can lead to cuts in government employment.",
      "Such measures may also lead to a contraction in public services and social programs.",
      "Foreign exchange markets are not directly affected by domestic employment policies."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Fiscal austerity measures typically result in reduced public sector spending, which can lead to cuts in government employment.",
        "Such measures may also lead to a contraction in public services and social programs."
      ]
    }
  },
  {
    "question": "How do bank stress tests influence market confidence?",
    "retrieved_chunks": [
      "Bank stress tests assess the resilience of financial institutions under adverse economic scenarios, which can boost market confidence when results are positive.",
      "They also serve as a signal to regulators and investors about the overall health of the banking sector.",
      "Cryptocurrency markets operate independently of traditional bank assessments."
    ],
    "final_answer": {
      "useful_count": 2,
      "ordered_chunks": [
        "Bank stress tests assess the resilience of financial institutions under adverse economic scenarios, which can boost market confidence when results are positive.",
        "They also serve as a signal to regulators and investors about the overall health of the banking sector."
      ]
    }
  }
]

# %% [markdown]
# # 2. Convert to dataset

# %%
from datasets import Dataset
import json
from pprint import pprint

dataset = Dataset.from_list(data)

print(dataset)
# Out:
# Dataset({
#     features: ['question', 'retrieved_chunks', 'final_answer'],
#     num_rows: 81
# })

# %%
pprint(dataset[0]['question'])
# Out:
# 'How does monetary policy influence inflation rates?'

# %%
pprint(dataset[0]['retrieved_chunks'])
# Out:
# ['Central banks implement monetary policy through instruments such as interest '
#  'rate adjustments, open market operations, and reserve requirements. By '
#  'lowering interest rates, banks aim to stimulate borrowing and investment, '
#  'while raising rates is used to cool down an overheating economy and mitigate '
#  'inflationary pressures.',
#  'Inflation is affected by the quantity of money in circulation relative to '
#  'goods and services available in the economy. When central banks increase the '
#  'money supply without a corresponding increase in production, the value of '
#  'money can decrease, leading to higher prices for consumers.',
#  'In addition to economic factors, central banks sometimes take into account '
#  'political stability and international market trends when deciding on policy '
#  'changes. However, these considerations are more peripheral and do not '
#  'directly explain the mechanism through which monetary policy impacts '
#  'inflation.']

# %%
pprint(dataset[0]['final_answer'])
# Out:
# {'ordered_chunks': ['Central banks implement monetary policy through '
#                     'instruments such as interest rate adjustments, open '
#                     'market operations, and reserve requirements. By lowering '
#                     'interest rates, banks aim to stimulate borrowing and '
#                     'investment, while raising rates is used to cool down an '
#                     'overheating economy and mitigate inflationary pressures.',
#                     'Inflation is affected by the quantity of money in '
#                     'circulation relative to goods and services available in '
#                     'the economy. When central banks increase the money supply '
#                     'without a corresponding increase in production, the value '
#                     'of money can decrease, leading to higher prices for '
#                     'consumers.'],
#  'useful_count': 2}

# %%
dataset.push_to_hub("financial_retreival_finetune_dataset", private=True)

# %%
dataset.push_to_hub("financial_retreival_finetune_dataset_public")

# %% [markdown]
# #3. Shuffle, split and add prompt field

# %%
from datasets import load_dataset

ds = load_dataset("AmrataYadav/financial_retreival_finetune_dataset_public")
# Out:
# README.md:   0%|          | 0.00/636 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/46.8k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/81 [00:00<?, ? examples/s]

# %%
def convert_to_chatml(example):
        example["prompt"] = f"question: {example['question']} \n\n Retrieved chunks: {example['retrieved_chunks']}"
        return example

# %%
chat_dataset = ds.map(convert_to_chatml)
# Out:
# Map:   0%|          | 0/81 [00:00<?, ? examples/s]

# %%
chat_dataset['train'][0]['prompt']
# Out:
# "question: How does monetary policy influence inflation rates? \n\n Retrieved chunks: ['Central banks implement monetary policy through instruments such as interest rate adjustments, open market operations, and reserve requirements. By lowering interest rates, banks aim to stimulate borrowing and investment, while raising rates is used to cool down an overheating economy and mitigate inflationary pressures.', 'Inflation is affected by the quantity of money in circulation relative to goods and services available in the economy. When central banks increase the money supply without a corresponding increase in production, the value of money can decrease, leading to higher prices for consumers.', 'In addition to economic factors, central banks sometimes take into account political stability and international market trends when deciding on policy changes. However, these considerations are more peripheral and do not directly explain the mechanism through which monetary policy impacts inflat
# ...

# %%
dataset = chat_dataset.shuffle(seed=42)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'retrieved_chunks', 'final_answer', 'prompt'],
#         num_rows: 81
#     })
# })

# %%
train_val_split = dataset['train'].train_test_split(test_size=0.3)

# %%
from datasets import DatasetDict
dataset = DatasetDict({
    "train": train_val_split["train"],
    "test": train_val_split["test"], # Keeping the original test set
})

print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'retrieved_chunks', 'final_answer', 'prompt'],
#         num_rows: 56
#     })
#     test: Dataset({
#         features: ['question', 'retrieved_chunks', 'final_answer', 'prompt'],
#         num_rows: 25
#     })
# })

# %%
train_val_split = dataset["train"].train_test_split(test_size=0.2)

# Creating a new DatasetDict with the split
dataset = DatasetDict({
    "train": train_val_split["train"],
    "validation": train_val_split["test"],
    "test": dataset["test"]  # Keeping the original test set
})

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'retrieved_chunks', 'final_answer', 'prompt'],
#         num_rows: 44
#     })
#     validation: Dataset({
#         features: ['question', 'retrieved_chunks', 'final_answer', 'prompt'],
#         num_rows: 12
#     })
#     test: Dataset({
#         features: ['question', 'retrieved_chunks', 'final_answer', 'prompt'],
#         num_rows: 25
#     })
# })

# %%
dataset.push_to_hub("AmrataYadav/fin_retrieval_checker_finetune_dataset")
